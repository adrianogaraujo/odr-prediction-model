# %% [markdown]
# # Análise de Justiça Algorítmica - Fairness

# %%
# Instalação do AIF360 (se necessário)
# !pip install aif360

from aif360.datasets import BinaryLabelDataset
from aif360.metrics import BinaryLabelDatasetMetric, ClassificationMetric
import pandas as pd
import numpy as np
