# %% [markdown]
# # Análise Exploratória - Plataforma ODR

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('../data/odr_disputas_simuladas.csv')
df.head()
